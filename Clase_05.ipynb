# %% [markdown]
# <a href="https://colab.research.google.com/github/UberSw/curso-introduccion-programacion-cientifica/blob/main/Clase_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
datos = [random.randint(0,10000) for i in range(10)]
